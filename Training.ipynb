# %% [markdown]
# Learning to use Pandas for Data Analysis

# %%
# Import the pandas package
import pandas as pd

# %%
## Read the customer table and assign it to 'customer' object
customer = pd.read_csv("customer.csv")

# %% [markdown]
# ### Exploring the data
#
#
# Exploring using .head() and .tail()

# %%
# call the customer table
customer.head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0            1         1       MARY     SMITH
# 1            2         1   PATRICIA   JOHNSON
# 2            3         1      LINDA  WILLIAMS
# 3            4         2    BARBARA     JONES
# 4            5         1  ELIZABETH     BROWN
#
#                                  email  address_id  activebool create_date  \
# 0        MARY.SMITH@sakilacustomer.org           5        True  2006-02-14
# 1  PATRICIA.JOHNSON@sakilacustomer.org           6        True  2006-02-14
# 2    LINDA.WILLIAMS@sakilacustomer.org           7        True  2006-02-14
# 3     BARBARA.JONES@sakilacustomer.org           8        True  2006-02-14
# 4   ELIZABETH.BROWN@sakilacustomer.org           9        True  2006-02-14
#
#            last_update  active
# 0  2006-02-15 09:57:20       1
# 1  2006-02-15 09:57:20       1
# 2  2006-02-15 09:57:20       1
# 3  2006-02-15 09:57:20       1
# 4  2006-02-15 09:57:20       1

# %%
customer.tail()
# Out:
#      customer_id  store_id first_name  last_name  \
# 594          595         1   TERRENCE  GUNDERSON
# 595          596         1    ENRIQUE   FORSYTHE
# 596          597         1    FREDDIE     DUGGAN
# 597          598         1       WADE   DELVALLE
# 598          599         2     AUSTIN    CINTRON
#
#                                      email  address_id  activebool  \
# 594  TERRENCE.GUNDERSON@sakilacustomer.org         601        True
# 595    ENRIQUE.FORSYTHE@sakilacustomer.org         602        True
# 596      FREDDIE.DUGGAN@sakilacustomer.org         603        True
# 597       WADE.DELVALLE@sakilacustomer.org         604        True
# 598      AUSTIN.CINTRON@sakilacustomer.org         605        True
#
#     create_date          last_update  active
# 594  2006-02-14  2006-02-15 09:57:20       1
# 595  2006-02-14  2006-02-15 09:57:20       1
# 596  2006-02-14  2006-02-15 09:57:20       1
# 597  2006-02-14  2006-02-15 09:57:20       1
# 598  2006-02-14  2006-02-15 09:57:20       1

# %%
# examine the tail
customer.sample(5)
# Out:
#      customer_id  store_id first_name last_name  \
# 318          319         2     RONALD    WEINER
# 568          569         2       DAVE  GARDINER
# 51            52         1      JULIE   SANCHEZ
# 203          204         1   ROSEMARY   SCHMIDT
# 108          109         2       EDNA      WEST
#
#                                    email  address_id  activebool create_date  \
# 318     RONALD.WEINER@sakilacustomer.org         324        True  2006-02-14
# 568     DAVE.GARDINER@sakilacustomer.org         575        True  2006-02-14
# 51      JULIE.SANCHEZ@sakilacustomer.org          56        True  2006-02-14
# 203  ROSEMARY.SCHMIDT@sakilacustomer.org         208        True  2006-02-14
# 108         EDNA.WEST@sakilacustomer.org         113        True  2006-02-14
#
#              last_update  active
# 318  2006-02-15 09:57:20       1
# 568  2006-02-15 09:57:20       1
# 51   2006-02-15 09:57:20       1
# 203  2006-02-15 09:57:20       1
# 108  2006-02-15 09:57:20       1

# %%
# examine column names
customer.columns
# Out:
# Index(['customer_id', 'store_id', 'first_name', 'last_name', 'email',
#        'address_id', 'activebool', 'create_date', 'last_update', 'active'],
#       dtype='object')

# %%
# examine the data types
customer.dtypes
# Out:
# customer_id     int64
# store_id        int64
# first_name     object
# last_name      object
# email          object
# address_id      int64
# activebool       bool
# create_date    object
# last_update    object
# active          int64
# dtype: object

# %%
# import the payment table and repeat the above
payment = pd.read_csv("payment.csv")
payment.head()
# Out:
#    payment_id  customer_id  staff_id  rental_id  amount  \
# 0       16050          269         2          7    1.99
# 1       16051          269         1         98    0.99
# 2       16052          269         2        678    6.99
# 3       16053          269         2        703    0.99
# 4       16054          269         1        750    4.99
#
#                  payment_date
# 0  2007-01-24 21:40:19.996577
# 1  2007-01-25 15:16:50.996577
# 2  2007-01-28 21:44:14.996577
# 3  2007-01-29 00:58:02.996577
# 4  2007-01-29 08:10:06.996577

# %%
# descriptive stats on the customer and payment tables
customer.describe()
# Out:
#        customer_id    store_id  address_id      active
# count   599.000000  599.000000  599.000000  599.000000
# mean    300.000000    1.455760  304.724541    0.974958
# std     173.060683    0.498455  173.698609    0.156382
# min       1.000000    1.000000    5.000000    0.000000
# 25%     150.500000    1.000000  154.500000    1.000000
# 50%     300.000000    1.000000  305.000000    1.000000
# 75%     449.500000    2.000000  454.500000    1.000000
# max     599.000000    2.000000  605.000000    1.000000

# %% [markdown]
# Why are only certain columns described?
# Ans - Because the method by default provides descriptive statistics for numerical columns. It calculates statistics such as count, mean, standard deviation, minimum, quartiles, and maximum for numerical data.
#
#
# What happens if we try and call describe on categorical columns?
# Ans - If you try to call describe() on categorical columns, it will provide descriptive statistics specific to categorical data. It will include the count of non-null values, the number of unique categories, the most frequent category, and the frequency of the most frequent category.

# %% [markdown]
# ### Selecting Columns
#
#
# A dataframe is a collection of `series`(columns), a `series` is a `numpy array` with an index

# %%
# select a column as a series
customer['first_name']
# Out:
# 0           MARY
# 1       PATRICIA
# 2          LINDA
# 3        BARBARA
# 4      ELIZABETH
#          ...
# 594     TERRENCE
# 595      ENRIQUE
# 596      FREDDIE
# 597         WADE
# 598       AUSTIN
# Name: first_name, Length: 599, dtype: object

# %%
# select a column as a dataframe
customer[['first_name']]
# Out:
#     first_name
# 0         MARY
# 1     PATRICIA
# 2        LINDA
# 3      BARBARA
# 4    ELIZABETH
# ..         ...
# 594   TERRENCE
# 595    ENRIQUE
# 596    FREDDIE
# 597       WADE
# 598     AUSTIN
#
# [599 rows x 1 columns]

# %%
# select multiple columns
customer[['first_name', 'last_name']]
# Out:
#     first_name  last_name
# 0         MARY      SMITH
# 1     PATRICIA    JOHNSON
# 2        LINDA   WILLIAMS
# 3      BARBARA      JONES
# 4    ELIZABETH      BROWN
# ..         ...        ...
# 594   TERRENCE  GUNDERSON
# 595    ENRIQUE   FORSYTHE
# 596    FREDDIE     DUGGAN
# 597       WADE   DELVALLE
# 598     AUSTIN    CINTRON
#
# [599 rows x 2 columns]

# %%
# describe first and last name columns
customer[['first_name', 'last_name']].describe()
# Out:
#        first_name last_name
# count         599       599
# unique        591       599
# top        JESSIE     SMITH
# freq            2         1

# %% [markdown]
# Describe a categorical column

# %%
# look at unique values for store_id
customer['store_id'].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
# using value counts
customer['store_id'].value_counts()
# Out:
# 1    326
# 2    273
# Name: store_id, dtype: int64

# %% [markdown]
# ### Plotting
#
# Lets find out how frequent different amounts are paid.

# %%
# call the payment table
payment = pd.read_csv('payment.csv')

# %%
payment.hist(column = 'amount');

# %%
# pandas method of histogram for amount in payment table
payment['amount'].hist(grid = False, bins = 12)
# Out:
# <AxesSubplot:>

# %%
# save the plot
plot = payment['amount'].hist(grid = False, bins = 12)
plot.set_title('amount of payment')
plot.get_figure().savefig('output.pdf', format='pdf')

# %% [markdown]
# ### Sorting

# %%
# sort by customers by name
customer.sort_values(by = 'first_name').head()
# Out:
#      customer_id  store_id first_name last_name  \
# 374          375         2      AARON     SELBY
# 366          367         1       ADAM     GOOCH
# 524          525         2     ADRIAN     CLARY
# 216          217         2      AGNES    BISHOP
# 388          389         1       ALAN      KAHN
#
#                                email  address_id  activebool create_date  \
# 374   AARON.SELBY@sakilacustomer.org         380        True  2006-02-14
# 366    ADAM.GOOCH@sakilacustomer.org         372        True  2006-02-14
# 524  ADRIAN.CLARY@sakilacustomer.org         531        True  2006-02-14
# 216  AGNES.BISHOP@sakilacustomer.org         221        True  2006-02-14
# 388     ALAN.KAHN@sakilacustomer.org         394        True  2006-02-14
#
#              last_update  active
# 374  2006-02-15 09:57:20       1
# 366  2006-02-15 09:57:20       1
# 524  2006-02-15 09:57:20       1
# 216  2006-02-15 09:57:20       1
# 388  2006-02-15 09:57:20       1

# %%
# sort by store_id and address_id
customer.sort_values(by = ['store_id', 'address_id'], ascending = False).head()
# Out:
#      customer_id  store_id first_name  last_name  \
# 598          599         2     AUSTIN    CINTRON
# 592          593         2       RENE  MCALISTER
# 589          590         2       SETH     HANNON
# 583          584         2   SALVADOR       TEEL
# 581          582         2       ANDY    VANHORN
#
#                                  email  address_id  activebool create_date  \
# 598  AUSTIN.CINTRON@sakilacustomer.org         605        True  2006-02-14
# 592  RENE.MCALISTER@sakilacustomer.org         599        True  2006-02-14
# 589     SETH.HANNON@sakilacustomer.org         596        True  2006-02-14
# 583   SALVADOR.TEEL@sakilacustomer.org         590        True  2006-02-14
# 581    ANDY.VANHORN@sakilacustomer.org         588        True  2006-02-14
#
#              last_update  active
# 598  2006-02-15 09:57:20       1
# 592  2006-02-15 09:57:20       1
# 589  2006-02-15 09:57:20       1
# 583  2006-02-15 09:57:20       1
# 581  2006-02-15 09:57:20       1

# %% [markdown]
# This does not alter the values in the dataframe, in order to do so we must reassign or use a flag for inplace, Re-assigning is the preferred method

# %%
# using inplace
customer.sort_values(by = 'first_name', inplace=True)
customer.head()
# Out:
#      customer_id  store_id first_name last_name  \
# 374          375         2      AARON     SELBY
# 366          367         1       ADAM     GOOCH
# 524          525         2     ADRIAN     CLARY
# 216          217         2      AGNES    BISHOP
# 388          389         1       ALAN      KAHN
#
#                                email  address_id  activebool create_date  \
# 374   AARON.SELBY@sakilacustomer.org         380        True  2006-02-14
# 366    ADAM.GOOCH@sakilacustomer.org         372        True  2006-02-14
# 524  ADRIAN.CLARY@sakilacustomer.org         531        True  2006-02-14
# 216  AGNES.BISHOP@sakilacustomer.org         221        True  2006-02-14
# 388     ALAN.KAHN@sakilacustomer.org         394        True  2006-02-14
#
#              last_update  active
# 374  2006-02-15 09:57:20       1
# 366  2006-02-15 09:57:20       1
# 524  2006-02-15 09:57:20       1
# 216  2006-02-15 09:57:20       1
# 388  2006-02-15 09:57:20       1

# %%
# reset by index
customer.sort_index(inplace=True)
customer.head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0            1         1       MARY     SMITH
# 1            2         1   PATRICIA   JOHNSON
# 2            3         1      LINDA  WILLIAMS
# 3            4         2    BARBARA     JONES
# 4            5         1  ELIZABETH     BROWN
#
#                                  email  address_id  activebool create_date  \
# 0        MARY.SMITH@sakilacustomer.org           5        True  2006-02-14
# 1  PATRICIA.JOHNSON@sakilacustomer.org           6        True  2006-02-14
# 2    LINDA.WILLIAMS@sakilacustomer.org           7        True  2006-02-14
# 3     BARBARA.JONES@sakilacustomer.org           8        True  2006-02-14
# 4   ELIZABETH.BROWN@sakilacustomer.org           9        True  2006-02-14
#
#            last_update  active
# 0  2006-02-15 09:57:20       1
# 1  2006-02-15 09:57:20       1
# 2  2006-02-15 09:57:20       1
# 3  2006-02-15 09:57:20       1
# 4  2006-02-15 09:57:20       1

# %%
# using reassignment
customer = customer.sort_values(by='first_name')

# %%
## Reset the index
customer.reset_index().head()
# Out:
#    index  customer_id  store_id first_name last_name  \
# 0    374          375         2      AARON     SELBY
# 1    366          367         1       ADAM     GOOCH
# 2    524          525         2     ADRIAN     CLARY
# 3    216          217         2      AGNES    BISHOP
# 4    388          389         1       ALAN      KAHN
#
#                              email  address_id  activebool create_date  \
# 0   AARON.SELBY@sakilacustomer.org         380        True  2006-02-14
# 1    ADAM.GOOCH@sakilacustomer.org         372        True  2006-02-14
# 2  ADRIAN.CLARY@sakilacustomer.org         531        True  2006-02-14
# 3  AGNES.BISHOP@sakilacustomer.org         221        True  2006-02-14
# 4     ALAN.KAHN@sakilacustomer.org         394        True  2006-02-14
#
#            last_update  active
# 0  2006-02-15 09:57:20       1
# 1  2006-02-15 09:57:20       1
# 2  2006-02-15 09:57:20       1
# 3  2006-02-15 09:57:20       1
# 4  2006-02-15 09:57:20       1

# %% [markdown]
# This creates a new column, order to do so without we drop the previous index

# %%
## Reset the index in place and drop previous index column
customer = customer.reset_index(drop=True)
customer.head()
# Out:
#    customer_id  store_id first_name last_name  \
# 0          375         2      AARON     SELBY
# 1          367         1       ADAM     GOOCH
# 2          525         2     ADRIAN     CLARY
# 3          217         2      AGNES    BISHOP
# 4          389         1       ALAN      KAHN
#
#                              email  address_id  activebool create_date  \
# 0   AARON.SELBY@sakilacustomer.org         380        True  2006-02-14
# 1    ADAM.GOOCH@sakilacustomer.org         372        True  2006-02-14
# 2  ADRIAN.CLARY@sakilacustomer.org         531        True  2006-02-14
# 3  AGNES.BISHOP@sakilacustomer.org         221        True  2006-02-14
# 4     ALAN.KAHN@sakilacustomer.org         394        True  2006-02-14
#
#            last_update  active
# 0  2006-02-15 09:57:20       1
# 1  2006-02-15 09:57:20       1
# 2  2006-02-15 09:57:20       1
# 3  2006-02-15 09:57:20       1
# 4  2006-02-15 09:57:20       1

# %% [markdown]
# ### Filtering Rows
#
#
# To look at subsets of the data, we will  filter or group required sets.

# %%
# Filter the table to just the store that we are interested in, store number 2
customer[customer['store_id'] == 2]
# Out:
#      customer_id  store_id first_name last_name  \
# 0            375         2      AARON     SELBY
# 2            525         2     ADRIAN     CLARY
# 3            217         2      AGNES    BISHOP
# 6            568         2    ALBERTO   HENNING
# 7            454         2       ALEX   GRESHAM
# ..           ...       ...        ...       ...
# 593          359         2     WILLIE   MARKHAM
# 594          219         2     WILLIE    HOWELL
# 595          212         2      WILMA  RICHARDS
# 596          190         2    YOLANDA    WEAVER
# 597          174         2     YVONNE   WATKINS
#
#                                   email  address_id  activebool create_date  \
# 0        AARON.SELBY@sakilacustomer.org         380        True  2006-02-14
# 2       ADRIAN.CLARY@sakilacustomer.org         531        True  2006-02-14
# 3       AGNES.BISHOP@sakilacustomer.org         221        True  2006-02-14
# 6    ALBERTO.HENNING@sakilacustomer.org         574        True  2006-02-14
# 7       ALEX.GRESHAM@sakilacustomer.org         459        True  2006-02-14
# ..                                  ...         ...         ...         ...
# 593   WILLIE.MARKHAM@sakilacustomer.org         364        True  2006-02-14
# 594    WILLIE.HOWELL@sakilacustomer.org         223        True  2006-02-14
# 595   WILMA.RICHARDS@sakilacustomer.org         216        True  2006-02-14
# 596   YOLANDA.WEAVER@sakilacustomer.org         194        True  2006-02-14
# 597   YVONNE.WATKINS@sakilacustomer.org         178        True  2006-02-14
#
#              last_update  active
# 0    2006-02-15 09:57:20       1
# 2    2006-02-15 09:57:20       1
# 3    2006-02-15 09:57:20       1
# 6    2006-02-15 09:57:20       1
# 7    2006-02-15 09:57:20       1
# ..                   ...     ...
# 593  2006-02-15 09:57:20       1
# 594  2006-02-15 09:57:20       1
# 595  2006-02-15 09:57:20       1
# 596  2006-02-15 09:57:20       1
# 597  2006-02-15 09:57:20       1
#
# [273 rows x 10 columns]

# %% [markdown]
# ## Explanation of whats going on in this operation

# %%
# Creating a Boolean mask to filter rows

store_id_filter = customer['store_id'] == 2
store_id_filter
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 594     True
# 595     True
# 596     True
# 597     True
# 598    False
# Name: store_id, Length: 599, dtype: bool

# %%
# Applying boolean mask to the dataframe
customer[store_id_filter]
# Out:
#      customer_id  store_id first_name last_name  \
# 0            375         2      AARON     SELBY
# 2            525         2     ADRIAN     CLARY
# 3            217         2      AGNES    BISHOP
# 6            568         2    ALBERTO   HENNING
# 7            454         2       ALEX   GRESHAM
# ..           ...       ...        ...       ...
# 593          359         2     WILLIE   MARKHAM
# 594          219         2     WILLIE    HOWELL
# 595          212         2      WILMA  RICHARDS
# 596          190         2    YOLANDA    WEAVER
# 597          174         2     YVONNE   WATKINS
#
#                                   email  address_id  activebool create_date  \
# 0        AARON.SELBY@sakilacustomer.org         380        True  2006-02-14
# 2       ADRIAN.CLARY@sakilacustomer.org         531        True  2006-02-14
# 3       AGNES.BISHOP@sakilacustomer.org         221        True  2006-02-14
# 6    ALBERTO.HENNING@sakilacustomer.org         574        True  2006-02-14
# 7       ALEX.GRESHAM@sakilacustomer.org         459        True  2006-02-14
# ..                                  ...         ...         ...         ...
# 593   WILLIE.MARKHAM@sakilacustomer.org         364        True  2006-02-14
# 594    WILLIE.HOWELL@sakilacustomer.org         223        True  2006-02-14
# 595   WILMA.RICHARDS@sakilacustomer.org         216        True  2006-02-14
# 596   YOLANDA.WEAVER@sakilacustomer.org         194        True  2006-02-14
# 597   YVONNE.WATKINS@sakilacustomer.org         178        True  2006-02-14
#
#              last_update  active
# 0    2006-02-15 09:57:20       1
# 2    2006-02-15 09:57:20       1
# 3    2006-02-15 09:57:20       1
# 6    2006-02-15 09:57:20       1
# 7    2006-02-15 09:57:20       1
# ..                   ...     ...
# 593  2006-02-15 09:57:20       1
# 594  2006-02-15 09:57:20       1
# 595  2006-02-15 09:57:20       1
# 596  2006-02-15 09:57:20       1
# 597  2006-02-15 09:57:20       1
#
# [273 rows x 10 columns]

# %%
# create a boolean mask where first name is Terry
# experiment with case
first_name_filter = customer['first_name'].str.upper() == 'TERRY'
first_name_filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 594    False
# 595    False
# 596    False
# 597    False
# 598    False
# Name: first_name, Length: 599, dtype: bool

# %%
# apply both filters
customer[store_id_filter & first_name_filter]
# Out:
#      customer_id  store_id first_name last_name  \
# 544          355         2      TERRY   GRISSOM
#
#                                 email  address_id  activebool create_date  \
# 544  TERRY.GRISSOM@sakilacustomer.org         360        True  2006-02-14
#
#              last_update  active
# 544  2006-02-15 09:57:20       1

# %% [markdown]
# # Aggregation

# %%
# total amount per customer
payment.groupby('customer_id').sum().head()
# Out:
#              payment_id  staff_id  rental_id  amount
# customer_id
# 1                760358        47     241137  118.68
# 2                690998        39     257716  128.73
# 3                643639        38     206151  135.74
# 4                506081        32     197174   81.78
# 5                934784        59     300857  144.62

# %%
payment[['customer_id', 'amount']].groupby('customer_id').sum()
# Out:
#              amount
# customer_id
# 1            118.68
# 2            128.73
# 3            135.74
# 4             81.78
# 5            144.62
# ...             ...
# 595          117.70
# 596           96.72
# 597           99.75
# 598           83.78
# 599           83.81
#
# [599 rows x 1 columns]

# %%
# agg with renaming the column
payment[['customer_id', 'amount']].groupby('customer_id').agg(total_amount = ('amount', 'sum'))
# Out:
#              total_amount
# customer_id
# 1                  118.68
# 2                  128.73
# 3                  135.74
# 4                   81.78
# 5                  144.62
# ...                   ...
# 595                117.70
# 596                 96.72
# 597                 99.75
# 598                 83.78
# 599                 83.81
#
# [599 rows x 1 columns]

# %% [markdown]
# Sort customers by descending total amount

# %%
# do again with renaming to total_amount
payment[['customer_id', 'amount']].groupby('customer_id'
                                          ).agg(total_amount=('amount','sum')
                                               ).sort_values(by='total_amount', ascending=False)
# Out:
#              total_amount
# customer_id
# 526                221.55
# 148                216.54
# 144                195.58
# 137                194.61
# 178                194.61
# ...                   ...
# 97                  58.82
# 395                 57.81
# 318                 52.88
# 281                 50.86
# 248                 50.85
#
# [599 rows x 1 columns]

# %%
# Find the staff member with the highest average sale
payment[['staff_id', 'amount']].groupby('staff_id'
                                       ).agg(avg_sale = ('amount','mean')
                                            ).sort_values(by='avg_sale', ascending=False)
# Out:
#           avg_sale
# staff_id
# 2         4.245125
# 1         4.156568

# %%
avg_sales_per_staff = payment[['staff_id', 'amount']].groupby('staff_id'
                                                            ).agg(avg_sale = ('amount','mean')
                                                                  ).sort_values(by='avg_sale', ascending=False)

# %%
# Save aggregation to csv 
# do again with index=False
avg_sales_per_staff.to_csv('avg_sales_per_staff.csv', index=False)

# %%
# Save to Excel
avg_sales_per_staff.to_excel('customer.xlsx', sheet_name='payment_details')

# %% [markdown]
# ### Joins

# %%
## Merge the DataFrames using the .merge() method
pd.merge(left = customer,
         right = payment,
         how = 'left',
         left_on = 'customer_id',
         right_on = 'customer_id'
        ).head()
# Out:
#    customer_id  store_id first_name last_name                           email  \
# 0          375         2      AARON     SELBY  AARON.SELBY@sakilacustomer.org
# 1          375         2      AARON     SELBY  AARON.SELBY@sakilacustomer.org
# 2          375         2      AARON     SELBY  AARON.SELBY@sakilacustomer.org
# 3          375         2      AARON     SELBY  AARON.SELBY@sakilacustomer.org
# 4          375         2      AARON     SELBY  AARON.SELBY@sakilacustomer.org
#
#    address_id  activebool create_date          last_update  active  \
# 0         380        True  2006-02-14  2006-02-15 09:57:20       1
# 1         380        True  2006-02-14  2006-02-15 09:57:20       1
# 2         380        True  2006-02-14  2006-02-15 09:57:20       1
# 3         380        True  2006-02-14  2006-02-15 09:57:20       1
# 4         380        True  2006-02-14  2006-02-15 09:57:20       1
#
#    payment_id  staff_id  rental_id  amount                payment_date
# 0       16253         2        307    8.99  2007-01-26 20:16:39.996577
# 1       16254         1        412    4.99  2007-01-27 12:45:49.996577
# 2       16255         2        749    4.99  2007-01-29 08:01:59.996577
# 3       16256         1        873    2.99  2007-01-30 03:43:46.996577
# 4       17634         2       1404    2.99  2007-02-15 15:07:19.996577
